# %%
import seaborn as sns
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_carat=diamonds.groupby('carat')

# %%
p = sns.kdeplot(diamonds.carat,
                color='#F15B2A',
                shade=True)
# Out:
# /var/folders/sb/8r1ll48x2md1p01_fzj423yh0000gn/T/ipykernel_18664/1947511394.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   p = sns.kdeplot(diamonds.carat,

# %%
diamonds_carat.describe()
# Out:
#        depth                                                          table  \
#        count       mean       std   min     25%    50%     75%   max  count
# carat
# 0.20    12.0  61.100000  1.399350  59.0  59.775  61.30  62.225  63.4   12.0
# 0.21     9.0  60.511111  1.523519  58.3  59.600  60.50  61.600  63.2    9.0
# 0.22     5.0  61.620000  2.178761  59.3  60.400  61.60  61.700  65.1    5.0
# 0.23   293.0  61.426621  1.451230  56.2  60.700  61.50  62.400  64.8  293.0
# 0.24   254.0  61.599213  1.317591  57.2  60.900  61.70  62.400  65.1  254.0
# ...      ...        ...       ...   ...     ...    ...     ...   ...    ...
# 4.00     1.0  63.300000       NaN  63.3  63.300  63.30  63.300  63.3    1.0
# 4.01     2.0  61.750000  1.060660  61.0  61.375  61.75  62.125  62.5    2.0
# 4.13     1.0  64.800000       NaN  64.8  64.800  64.80  64.800  64.8    1.0
# 4.50     1.0  65.800000       NaN  65.8  65.800  65.80  65.800  65.8    1.0
# ...

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
diamonds_color = diamonds.groupby('color')

# %%
diamonds_e = diamonds[diamonds['color'] == 'E']

diamonds_e.reset_index(inplace=True)

diamonds_e.head()

#making a DF that only contains the color E
# Out:
#    index  carat      cut color clarity  depth  table  price     x     y     z
# 0      0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1      1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      8   0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 4     14   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27

# %%
diamonds_f = diamonds[diamonds['color'] == 'F']

diamonds_f.reset_index(inplace=True)

diamonds_f.head()

#making a DF that only contains the color F
# Out:
#    index  carat        cut color clarity  depth  table  price     x     y  \
# 0     12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84
# 1     29   0.23  Very Good     F     VS1   60.9   57.0    357  3.96  3.99
# 2     30   0.23  Very Good     F     VS1   60.0   57.0    402  4.00  4.03
# 3     31   0.23  Very Good     F     VS1   59.8   57.0    402  4.04  4.06
# 4     35   0.23       Good     F     VS1   58.2   59.0    402  4.06  4.08
#
#       z
# 0  2.33
# 1  2.42
# 2  2.41
# 3  2.42
# 4  2.37

# %%
stats.ttest_ind(diamonds_e['carat'], diamonds_f['carat']) 

#null hypothesis: the mean carats of diamonds with color E is the same as the mean carat of diamonds with color F

#the result: reject null hypothesis; the mean carats of color E and F are not the same
# Out:
# Ttest_indResult(statistic=-14.275372025770679, pvalue=5.338854967626809e-46)

# %% [markdown]
# ### Multivariate Analysis

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize = (15,8))

sns.scatterplot(x='carat', y='price', data = diamonds, color='#b3b3ff', ax=ax)

#scatter plot to show the relationship between carat value and price of the diamonds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 7
#       3 sns.scatterplot(x='carat', y='price', data = diamonds, color='#b3b3ff', ax=ax)
#       5 #scatter plot to show the relationship between carat value and price of the diamonds
# ----> 7 plt.plot(x,a*x+b)
#
# NameError: name 'x' is not defined

# %%
x = diamonds['carat']

y = diamonds['price']

a, b = np.polyfit(x,y,1)

# %%
plt.scatter(x,y,color='#b3b3ff')
plt.title("The relationship between carat and price of the diamonds")
plt.xlabel("Carats")
plt.ylabel("Price in USD")
plt.show()
plt.plot(x, a*x+b)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 x = df[:,0]
#       2 y = df[:,1]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
