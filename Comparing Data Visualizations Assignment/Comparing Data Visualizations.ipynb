# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('countries.csv')

# %%
df.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
df_1952 = df[df.year==1952]

# %%
df_1952
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 0            Afghanistan      Asia  1952          28.801     8425333
# 12               Albania    Europe  1952          55.230     1282697
# 24               Algeria    Africa  1952          43.077     9279525
# 36                Angola    Africa  1952          30.015     4232095
# 48             Argentina  Americas  1952          62.485    17876956
# ...                  ...       ...   ...             ...         ...
# 1644             Vietnam      Asia  1952          40.412    26246839
# 1656  West Bank and Gaza      Asia  1952          43.160     1030585
# 1668         Yemen, Rep.      Asia  1952          32.548     4963829
# 1680              Zambia    Africa  1952          42.038     2672000
# 1692            Zimbabwe    Africa  1952          48.451     3080907
#
#       gdpPerCapita
# 0       779.445314
# 12     1601.056136
# 24     2449.008185
# 36     3520.610273
# 48     5911.315053
# ...

# %%
df_1952_africa = df_1952[df_1952.continent=='Africa']

# %%
df_1952_africa
# Out:
#                        country continent  year  lifeExpectancy  population  \
# 24                     Algeria    Africa  1952          43.077     9279525
# 36                      Angola    Africa  1952          30.015     4232095
# 120                      Benin    Africa  1952          38.223     1738315
# 156                   Botswana    Africa  1952          47.622      442308
# 192               Burkina Faso    Africa  1952          31.975     4469979
# 204                    Burundi    Africa  1952          39.031     2445618
# 228                   Cameroon    Africa  1952          38.523     5009067
# 252   Central African Republic    Africa  1952          35.463     1291695
# 264                       Chad    Africa  1952          38.092     2682462
# 312                    Comoros    Africa  1952          40.715      153936
# 324           Congo, Dem. Rep.    Africa  1952          39.143    14100005
# ...

# %%
df_1952_asia = df_1952[df_1952.continent == 'Asia']

# %%
df_1952_asia.head()
# Out:
#          country continent  year  lifeExpectancy  population  gdpPerCapita
# 0    Afghanistan      Asia  1952          28.801     8425333    779.445314
# 84       Bahrain      Asia  1952          50.939      120447   9867.084765
# 96    Bangladesh      Asia  1952          37.484    46886859    684.244172
# 216     Cambodia      Asia  1952          39.417     4693836    368.469286
# 288        China      Asia  1952          44.000   556263527    400.448611

# %%
plt.hist(df_1952_africa.lifeExpectancy, 20)
# Out:
# (array([3., 2., 2., 4., 2., 4., 3., 7., 3., 4., 7., 4., 1., 1., 1., 1., 1.,
#         0., 1., 1.]),
#  array([30.    , 31.1362, 32.2724, 33.4086, 34.5448, 35.681 , 36.8172,
#         37.9534, 39.0896, 40.2258, 41.362 , 42.4982, 43.6344, 44.7706,
#         45.9068, 47.043 , 48.1792, 49.3154, 50.4516, 51.5878, 52.724 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_1952_asia.lifeExpectancy, 20)
# Out:
# (array([1., 0., 1., 0., 6., 1., 2., 4., 2., 2., 3., 1., 2., 0., 2., 1., 1.,
#         2., 1., 1.]),
#  array([28.801  , 30.63045, 32.4599 , 34.28935, 36.1188 , 37.94825,
#         39.7777 , 41.60715, 43.4366 , 45.26605, 47.0955 , 48.92495,
#         50.7544 , 52.58385, 54.4133 , 56.24275, 58.0722 , 59.90165,
#         61.7311 , 63.56055, 65.39   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.subplot(2,1,1)
plt.title('Distribution of Life Expectancy in 1952')
plt.hist(df_1952_africa.lifeExpectancy, 20, range = (25,))
plt.ylabel('Africa')
plt.subplot(2,1,2)
plt.hist(df_1952_asia.lifeExpectancy, 20)
plt.ylabel('Asia')
# Out:
# Text(0, 0.5, 'Asia')
