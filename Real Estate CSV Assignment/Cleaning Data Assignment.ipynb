# %%
import pandas as pd

# %%
data = pd.read_csv('Realestate.csv')

# %%
data.dtypes
# Out:
# No                               int64
# transaction                    float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# numberOfConvenienceStores        int64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# dtype: object

# %%
data #shows the entire imported dataframe
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1

# %%
norm = ((data.houseAge - data.houseAge.mean())/data.houseAge.std())

# %%
norm
# Out:
# 0      1.258245
# 1      0.164474
# 2     -0.378037
# 3     -0.378037
# 4     -1.104301
#          ...
# 413   -0.343036
# 414   -1.051800
# 415    0.103223
# 416   -0.833046
# 417   -0.973048
# Name: houseAge, Length: 418, dtype: float64

# %%
data['houseAgeStandardized'] = norm #creates a new column named houseAgeStandardized with the normalized values

# %%
data.head() #shows the first 5 rows of the data
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    houseAgeStandardized
# 0              1.258245
# 1              0.164474
# 2             -0.378037
# 3             -0.378037
# 4             -1.104301

# %%
data.drop(axis = 1, 'numberOfConvenienceStores')
# Out:
#   Cell In[10], line 1
#     data.drop(axis = 1, 'numberOfConvenienceStores')
#                                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
data.drop(axis = 1, ['numberOfConvenienceStores']) #drops the specified column
# Out:
#   Cell In[11], line 1
#     data.drop(axis = 1, ['numberOfConvenienceStores']) #drops the specified column
#                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
data.drop(columns=['numberOfConvenienceStores']) #drops the spceified column
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop(columns=['numberOfConvenienceStores'], inplace = True) #applies the change to the original dataframe

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1     2012.917      32.0                     84.87882  24.98298
# 1   2     2012.917      19.5                    306.59470  24.98034
# 2   3     2013.583      13.3                    561.98450  24.98746
# 3   4     2013.500      13.3                    561.98450  24.98746
# 4   5     2012.833       5.0                    390.56840  24.97937
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 3  121.54391                  54.8             -0.378037
# 4  121.54245                  43.1             -1.104301

# %%
data.rename(columns = {'transaction' : 'transactionDate'}) #changes the column name as specified
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.rename(columns = {'transaction' : 'transactionDate'}, inplace = True)

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917      32.0                     84.87882  24.98298
# 1   2         2012.917      19.5                    306.59470  24.98034
# 2   3         2013.583      13.3                    561.98450  24.98746
# 3   4         2013.500      13.3                    561.98450  24.98746
# 4   5         2012.833       5.0                    390.56840  24.97937
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 3  121.54391                  54.8             -0.378037
# 4  121.54245                  43.1             -1.104301

# %%
data.loc[0:10, :] #shows the rows 0-10 with all of the columns
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 1    2         2012.917      19.5                    306.59470  24.98034
# 2    3         2013.583      13.3                    561.98450  24.98746
# 3    4         2013.500      13.3                    561.98450  24.98746
# 4    5         2012.833       5.0                    390.56840  24.97937
# 5    6         2012.667       7.1                   2175.03000  24.96305
# 6    7         2012.667      34.5                    623.47310  24.97933
# 7    8         2013.417      20.3                    287.60250  24.98042
# 8    9         2013.500      31.7                   5512.03800  24.95095
# 9   10         2013.417      17.9                   1783.18000  24.96731
# 10  11         2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.iloc[0:10, :] #iloc is exclusive of the ending range and uses the positional integer, index
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917      32.0                     84.87882  24.98298
# 1   2         2012.917      19.5                    306.59470  24.98034
# 2   3         2013.583      13.3                    561.98450  24.98746
# 3   4         2013.500      13.3                    561.98450  24.98746
# 4   5         2012.833       5.0                    390.56840  24.97937
# 5   6         2012.667       7.1                   2175.03000  24.96305
# 6   7         2012.667      34.5                    623.47310  24.97933
# 7   8         2013.417      20.3                    287.60250  24.98042
# 8   9         2013.500      31.7                   5512.03800  24.95095
# 9  10         2013.417      17.9                   1783.18000  24.96731
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
data.duplicated(subset=['latitude','longitude'])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 413     True
# 414     True
# 415    False
# 416     True
# 417     True
# Length: 418, dtype: bool

# %%
data.drop_duplicates(inplace = True) #deleted rows that were complete duplicates, which were 4 rows
#and applied it to the original dataframe

# %%
data[data.isna().any(axis=1)] #shows all rows with NaN in the entire dataframe
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 27  28         2013.250      10.4                    276.44900  24.95593
# 37  38         2013.167      12.0                   1360.13900  24.95204
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 0   121.54024                   NaN              1.258245
# 27  121.53913                   NaN             -0.631792
# 37  121.54842                   NaN             -0.491789

# %%
data.housePriceOfUnitArea.mean() #find the mean of the specified column
# Out:
# 38.03373493975904

# %%
from numpy import nan

# %%
data.replace({'housePriceOfUnitArea' : {nan : data.housePriceOfUnitArea.mean()}}, inplace = True) 
#replace nan to mean value of the column
#applied the changes to the original dataframe

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...
